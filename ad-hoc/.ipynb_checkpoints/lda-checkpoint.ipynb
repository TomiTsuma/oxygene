# %%
import spacy
import re
import nltk
import numpy as np
import pandas as pd
from pprint import pprint
import pickle
import gensim
import logging
import warnings
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.models.ldamodel import LdaModel
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
import pyLDAvis
from gensim.models.phrases import Phraser

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.19.2

# %%
df = pd.read_parquet("../data/nation.parquet")

# %%
stopwords = nltk.corpus.stopwords.words('english')

# %%
def remove_emails_nl_quotes(sentence):
    if (sentence is np.nan):
        return
    sentence = re.sub('\S*@\S*\s?', '', sentence)
    sentence = re.sub('\s+', ' ', sentence)
    sentence = re.sub("\'", "", sentence)
    sentence = gensim.utils.simple_preprocess(str(sentence), deacc=True)
    return sentence

# %%
def remove_urls(text):
    url_pattern = r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+|www\.[a-zA-Z0-9./]+'
    clean_text = re.sub(url_pattern, '', text)
    return clean_text

# %%
def word_tokenization(sentence):
    return [token for token in sentence if token not in stopwords]

# %%
def preprocessing(df):
    df.dropna(inplace=True)
    df['Preprocessed'] = df['Review'].apply(remove_emails_nl_quotes)
    df['No_Stopwords'] = df['Preprocessed'].apply(word_tokenization)
    data_words = df['No_Stopwords'].values
    bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100)
    trigram = gensim.models.Phrases(bigram[data_words], threshold=100)
    bigram_model = gensim.models.phrases.Phraser(bigram)
    trigram_model = gensim.models.phrases.Phraser(trigram)

    texts = data_words
    texts = [bigram_model[doc] for doc in texts]
    texts = [trigram_model[bigram_model[doc]] for doc in texts]
    texts_out = []
    nlp = spacy.load("en_core_web_sm")
    allowed_postags = ['NOUN', 'ADJ', 'VERB', 'ADV']
    for sent in texts:
        doc = nlp(" ".join(sent))
        texts_out.append(
            [token.lemma_ for token in doc if token.pos_ in allowed_postags])
        texts_out = [[word for word in simple_preprocess(
            str(doc)) if word not in stopwords] for doc in texts_out]

    data_ready = texts_out
    return data_ready

# %%
def train_lda(num_topics, df):
    data = preprocessing(df)
    id2word = corpora.Dictionary(data)
    pickle.dump(id2word, open('lda_topic_modelling/bagofwords.bow', 'wb'))
    corpus = [id2word.doc2bow(text) for text in data]
    pickle.dump(corpus, open('lda_topic_modelling/corpus.corpora', 'wb'))
    lda_model = LdaModel(corpus=corpus, id2word=id2word, num_topics=num_topics, random_state=100, update_every=1, chunksize=10,
                         passes=5, alpha='symmetric', iterations=100,
                         per_word_topics=True)
    pickle.dump(lda_model, open('lda_topic_modelling/lda.sav', 'wb'))
    df_topics_sents_keywords = format_topic_sentences(
        ldamodel=lda_model, corpus=corpus, texts=data)
    df_topics_sents_keywords['Review'] = df['Review'].values
    df_dominant_topic = df_topics_sents_keywords.reset_index()
    df_dominant_topic.to_parquet('../data/dominant_topic.csv')
    return df_dominant_topic

# %%
text_data =[i.split(" ") for i in df['paragraphs']]

# %%
dictionary = corpora.Dictionary(text_data)
corpus = [dictionary.doc2bow(text) for text in text_data]

# %%
NUM_TOPICS = 10
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)

# %%
import pyLDAvis.gensim

lda_display = pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.2.2/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el
ited", "Olympian", "Masengeli", "settle", "blames", "matters", "talks.", "police", "discuss", "say", "she", "On", "save", "public", "planning", "they", "only", "through", "stand", "the", "of", "to", "and", "at", "from", "for", "was", "No", "purchases\nPleaselog", "him.", "Court", "communities.\nWould", "occasion", "quickly.\nCircumcision", "Methodist", "sets", "acts", "mark", "deep", "part", "fire", "pulpit\nDamaris", "winds", "aim", "justice", "angry", "Gachagua\u2019s", "kin", "inferno", "villagers", "resident", "17," ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 lda_display.display()
#
# AttributeError: 'PreparedData' object has no attribute 'display'

# %%
for sentence in df['paragraphs'].values:
    print(gensim.utils.simple_preprocess(str(sentence), deacc = True))
# Out:
# ['no', 'purchases', 'pleaselog', 'in']
# ['daniel', 'mururu', 'is', 'accused', 'of', 'radicalisation', 'defiling', 'underage', 'girls', 'and', 'raping', 'women', 'daniel', 'mururu', 'is', 'accused', 'of', 'radicalisation', 'defiling', 'underage', 'girls', 'and', 'raping', 'women', 'the', 'senate', 'argues', 'that', 'the', 'high', 'court', 'order', 'violates', 'natural', 'justice', 'by', 'excluding', 'the', 'legislative', 'body', 'from', 'the', 'proceedings', 'pastor', 'bizarre', 'rituals', 'blood', 'sprinkling', 'forced', 'sexual', 'acts', 'on', 'the', 'pulpit', 'damaris', 'kathira', 'and', 'her', 'friends', 'planned', 'for', 'an', 'occasion', 'to', 'mark', 'new', 'chapter', 'in', 'their', 'lives', 'kenha', 'officials', 'outline', 'three', 'options', 'to', 'end', 'slaughter', 'at', 'the', 'killer', 'bridge', 'in', 'tharaka', 'nithi', 'the', 'van', 'was', 'part', 'of', 'convoy', 'carrying', 'group', 'of', 'friends', 'who', 'were', 'in', 'meru', 'for', 'parental', 'blessing', 'ceremony', 'four', 'victims', 'succumb', 'to', 'deep', 'machete', 'cuts', 'as', 'angry', 'villagers', 'beat', 'the', 'assailant', 'to', 'death', 'residents', 'accuse', 'pastor', 'of', 'engaging', 'in', 'activities', 'bordering', 'on', 'cultism', 'neighbours', 'tried', 'to', 'put', 'out', 'the', 'fire', 'but', 'strong', 'winds', 'made', 'the', 'inferno', 'spread', 'quickly', 'circumcision', 'is', 'one', 'of', 'the', 'most', 'important', 'ceremonies', 'in', 'the', 'area', 'communities', 'would', 'the', 'tragedy', 'have', 'been', 'averted', 'had', 'the', 'police', 'taken', 'seriously', 'complaints', 'by', 'the', 'family', 'that', 'their', 'kin', 'was', 'thief', 'we', 'are', 'living', 'in', 'fear', 'of', 'being', 'attacked', 'it', 'is', 'no', 'longer', 'safe', 'resident', 'said', 'mp', 'says', 'gachagua', 'aim', 'is', 'to', 'weaken', 'president', 'william', 'ruto', 'influence', 'in', 'mt', 'kenya', 'an', 'ordained', 'methodist', 'reverend', 'and', 'civil', 'servant', 'mr', 'mutuma', 'joined', 'politics', 'in', 'high', 'court', 'certifies', 'her', 'case', 'as', 'urgent', 'sets', 'mention', 'on', 'september']
# ['president', 'william', 'ruto', 'shakes', 'hands', 'with', 'chinese', 'president', 'xi', 'jinping', 'during', 'bilateral', 'talks', 'at', 'the', 'great', 'hall', 'of', 'the', 'people', 'in', 'beijing', 'on', 'september', 'byjaindi', 'kisero', 'former', 'nation', 'media', 'group', 'managing', 'editor', 'for', 'business', 'and', 'economic', 'affairs', 'president', 'william', 'ruto', 'is', 'back', 'on', 'the', 'global', 'stage', 'leading', 'large', 'delegation', 'to', 'china', 'to', 'attend', 'the', 'latest', 'version', 'of', 'the', 'forum', 'on', 'china', 'africa', 'cooperation', 'focac', 'china', 'is', 'very', 'important', 'to', 'us', 'in', 'the', 'month', 'of', 'july', 'this', 'year', 'alone', 'we', 'had', 'to', 'cough', 'out', 'whopping', 'sh', 'billion', 'to', 'repay', 'chinese', 'loans', 'the', 'impact', 'on', 'our', 'cash', 'flows', 'is', 'such', 'that', 'when', 'repayments', 'of', 'chinese', 'debts', 'come', 'up', 'in', 'the', 'months', 'of', 'july', 'and', 'january', 'the', 'government', 'literally', 'freezes', 'development', 'spending', 'if', 'you', 'think', 'am', 'exaggerating', 'just', 'download', 'the', 'latest', 'monthly', 'budget', 'outturn', 'which', 'is', 'published', 'regularly', 'by', 'the', 'national', 'treasury', 'repayment', 'of', 'chinese', 'loans', 'is', 'also', 'almost', 'crowding', 'out', 'exchequer', 'releases', 'to', 'pensions', 'and', 'to', 'constitutional', 'bodies', 'but', 'as', 'president', 'ruto', 'returns', 'to', 'the', 'global', 'stage', 'the', 'big', 'question', 'remains', 'where', 'do', 'we', 'as', 'country', 'stand', 'in', 'today', 'version', 'of', 'the', 'cold', 'war', 'the', 'information', 'and', 'economic', 'war', 'between', 'china', 'and', 'russia', 'on', 'the', 'one', 'hand', 'and', 'the', 'us', 'and', 'its', 'allies', 'since', 'that', 'famous', 'statement', 'by', 'ambassador', 'martin', 'kimani', 'at', 'the', 'united', 'nations', 'security', 'council', 'can', 'we', 'still', 'claim', 'to', 'be', 'among', 'the', 'strongest', 'voices', 'in', 'africa', 'against', 'the', 'russian', 'illegal', 'aggression', 'against', 'ukraine', 'we', 'have', 'to', 'take', 'clear', 'and', 'strong', 'positions', 'because', 'we', 'are', 'in', 'the', 'middle', 'of', 'increasing', 'competition', 'for', 'geopolitical', 'and', 'geo', 'economics', 'global', 'dominance', 'today', 'the', 'us', 'company', 'starlink', 'has', 'emerged', 'ahead', 'after', 'launching', 'the', 'first', 'low', 'earth', 'orbit', 'satellite', 'leo', 'that', 'has', 'capability', 'to', 'provide', 'direct', 'to', 'device', 'communication', 'thereby', 'posing', 'big', 'threat', 'to', 'incumbent', 'mobile', 'network', 'operators', 'read', 'somewhere', 'how', 'china', 'is', 'also', 'prepping', 'its', 'own', 'expansive', 'and', 'major', 'leo', 'constellation', 'as', 'an', 'alternative', 'to', 'initiatives', 'from', 'us', 'europe', 'and', 'japan', 'the', 'predictions', 'right', 'now', 'are', 'that', 'china', 'and', 'russia', 'want', 'to', 'leverage', 'on', 'their', 'diplomatic', 'influence', 'and', 'relationships', 'in', 'africa', 'to', 'favour', 'the', 'entry', 'of', 'chinese', 'leo', 'operators', 'especially', 'when', 'it', 'comes', 'to', 'regulatory', 'market', 'access', 'the', 'competition', 'is', 'expected', 'to', 'be', 'stiff', 'because', 'africa', 'is', 'the', 'place', 'expected', 'to', 'produce', 'anticipated', 'future', 'revenues', 'for', 'most', 'leo', 'operators', 'stakes', 'are', 'even', 'higher', 'because', 'of', 'the', 'growing', 'two', 'fold', 'civilian', 'military', 'use', 'of', 'leo', 'kenya', 'and', 'indeed', 'africa', 'as', 'whole', 'must', 'take', 'firm', 'stand', 'and', 'speak', 'more', 'vociferously', 'on', 'the', 'prevailing', 'geopolitical', 'tensions', 'the', 'negative', 'impact', 'of', 'the', 'illegal', 'russian', 'invasion', 'of', 'ukraine', 'on', 'the', 'economies', 'of', 'the', 'continent', 'is', 'not', 'getting', 'adequate', 'articulation', 'in', 'international', 'fora', 'yet', 'many', 'countries', 'on', 'the', 'continen ...
# ['president', 'william', 'ruto', 'shakes', 'hands', 'with', 'chinese', 'president', 'xi', 'jinping', 'during', 'bilateral', 'talks', 'at', 'the', 'great', 'hall', 'of', 'the', 'people', 'in', 'beijing', 'on', 'september', 'byjaindi', 'kisero', 'former', 'nation', 'media', 'group', 'managing', 'editor', 'for', 'business', 'and', 'economic', 'affairs', 'president', 'william', 'ruto', 'is', 'back', 'on', 'the', 'global', 'stage', 'leading', 'large', 'delegation', 'to', 'china', 'to', 'attend', 'the', 'latest', 'version', 'of', 'the', 'forum', 'on', 'china', 'africa', 'cooperation', 'focac', 'china', 'is', 'very', 'important', 'to', 'us', 'in', 'the', 'month', 'of', 'july', 'this', 'year', 'alone', 'we', 'had', 'to', 'cough', 'out', 'whopping', 'sh', 'billion', 'to', 'repay', 'chinese', 'loans', 'the', 'impact', 'on', 'our', 'cash', 'flows', 'is', 'such', 'that', 'when', 'repayments', 'of', 'chinese', 'debts', 'come', 'up', 'in', 'the', 'months', 'of', 'july', 'and', 'january', 'the', 'government', 'literally', 'freezes', 'development', 'spending', 'if', 'you', 'think', 'am', 'exaggerating', 'just', 'download', 'the', 'latest', 'monthly', 'budget', 'outturn', 'which', 'is', 'published', 'regularly', 'by', 'the', 'national', 'treasury', 'repayment', 'of', 'chinese', 'loans', 'is', 'also', 'almost', 'crowding', 'out', 'exchequer', 'releases', 'to', 'pensions', 'and', 'to', 'constitutional', 'bodies', 'but', 'as', 'president', 'ruto', 'returns', 'to', 'the', 'global', 'stage', 'the', 'big', 'question', 'remains', 'where', 'do', 'we', 'as', 'country', 'stand', 'in', 'today', 'version', 'of', 'the', 'cold', 'war', 'the', 'information', 'and', 'economic', 'war', 'between', 'china', 'and', 'russia', 'on', 'the', 'one', 'hand', 'and', 'the', 'us', 'and', 'its', 'allies', 'since', 'that', 'famous', 'statement', 'by', 'ambassador', 'martin', 'kimani', 'at', 'the', 'united', 'nations', 'security', 'council', 'can', 'we', 'still', 'claim', 'to', 'be', 'among', 'the', 'strongest', 'voices', 'in', 'africa', 'against', 'the', 'russian', 'illegal', 'aggression', 'against', 'ukraine', 'we', 'have', 'to', 'take', 'clear', 'and', 'strong', 'positions', 'because', 'we', 'are', 'in', 'the', 'middle
treasury', 'repayment', 'of', 'chinese', 'loans', 'is', 'also', 'almost', 'crowding', 'out', 'exchequer', 'releases', 'to', 'pensions', 'and', 'to', 'constitutional', 'bodies', 'but', 'as', 'president', 'ruto', 'returns', 'to', 'the', 'global', 'stage', 'the', 'big', 'question', 'remains', 'where', 'do', 'we', 'as', 'country', 'stand', 'in', 'today', 'version', 'of', 'the', 'cold', 'war', 'the', 'information', 'and', 'economic', 'war', 'between', 'china', 'and', 'russia', 'on', 'the', 'one', 'hand', 'and', 'the', 'us', 'and', 'its', 'allies', 'since', 'that', 'famous', 'statement', 'by', 'ambassador', 'martin', 'kimani', 'at', 'the', 'united', 'nations', 'security', 'council', 'can', 'we', 'still', 'claim', 'to', 'be', 'among', 'the', 'strongest', 'voices', 'in', 'africa', 'against', 'the', 'russian', 'illegal', 'aggression', 'against', 'ukraine', 'we', 'have', 'to', 'take', 'clear', 'and', 'strong', 'positions', 'because', 'we', 'are', 'in', 'the', 'middle', 'of', 'increasing', 'competition', 'for', 'geopolitical', 'and', 'geo', 'economics', 'global', 'dominance', 'today', 'the', 'us', 'company', 'starlink', 'has', 'emerged', 'ahead', 'after', 'launching', 'the', 'first', 'low', 'earth', 'orbit', 'satellite', 'leo', 'that', 'has', 'capability', 'to', 'provide', 'direct', 'to', 'device', 'communication', 'thereby', 'posing', 'big', 'threat', 'to', 'incumbent', 'mobile', 'network', 'operators', 'read', 'somewhere', 'how', 'china', 'is', 'also', 'prepping', 'its', 'own', 'expansive', 'and', 'major', 'leo', 'constellation', 'as', 'an', 'alternative', 'to', 'initiatives', 'from', 'us', 'europe', 'and', 'japan', 'the', 'predictions', 'right', 'now', 'are', 'that', 'china', 'and', 'russia', 'want', 'to', 'leverage', 'on', 'their', 'diplomatic', 'influence', 'and', 'relationships', 'in', 'africa', 'to', 'favour', 'the', 'entry', 'of', 'chinese', 'leo', 'operators', 'especially', 'when', 'it', 'comes', 'to', 'regulatory', 'market', 'access', 'the', 'competition', 'is', 'expected', 'to', 'be', 'stiff', 'because', 'africa', 'is', 'the', 'place', 'expected', 'to', 'produce', 'anticipated', 'future', 'revenues', 'for', 'most', 'leo', 'operators', 'stakes', 'are', 'even', 'higher', 'because', 'of', 'the', 'growing', 'two', 'fold', 'civilian', 'military', 'use', 'of', 'leo', 'kenya', 'and', 'indeed', 'africa', 'as', 'whole', 'must', 'take', 'firm', 'stand', 'and', 'speak', 'more', 'vociferously', 'on', 'the', 'prevailing', 'geopolitical', 'tensions', 'the', 'negative', 'impact', 'of', 'the', 'illegal', 'russian', 'invasion', 'of', 'ukraine', 'on', 'the', 'economies', 'of', 'the', 'continent', 'is', 'not', 'getting', 'adequate', 'articulation', 'in', 'international', 'fora', 'yet', 'many', 'countries', 'on', 'the', 'continen ...
# ['president', 'william', 'ruto', 'shakes', 'hands', 'with', 'chinese', 'president', 'xi', 'jinping', 'during', 'bilateral', 'talks', 'at', 'the', 'great', 'hall', 'of', 'the', 'people', 'in', 'beijing', 'on', 'september', 'byjaindi', 'kisero', 'former', 'nation', 'media', 'group', 'managing', 'editor', 'for', 'business', 'and', 'economic', 'affairs', 'president', 'william', 'ruto', 'is', 'back', 'on', 'the', 'global', 'stage', 'leading', 'large', 'delegation', 'to', 'china', 'to', 'attend', 'the', 'latest', 'version', 'of', 'the', 'forum', 'on', 'china', 'africa', 'cooperation', 'focac', 'china', 'is', 'very', 'important', 'to', 'us', 'in', 'the', 'month', 'of', 'july', 'this', 'year', 'alone', 'we', 'had', 'to', 'cough', 'out', 'whopping', 'sh', 'billion', 'to', 'repay', 'chinese', 'loans', 'the', 'impact', 'on', 'our', 'cash', 'flows', 'is', 'such', 'that', 'when', 'repayments', 'of', 'chinese', 'debts', 'come', 'up', 'in', 'the', 'months', 'of', 'july', 'and', 'january', 'the', 'government', 'literally', 'freezes', 'development', 'spending', 'if', 'you', 'think', 'am', 'exaggerating', 'just', 'download', 'the', 'latest', 'monthly', 'budget', 'outturn', 'which', 'is', 'published', 'regularly', 'by', 'the', 'national', 'treasury', 'repayment', 'of', 'chinese', 'loans', 'is', 'also', 'almost', 'crowding', 'out', 'exchequer', 'releases', 'to', 'pensions', 'and', 'to', 'constitutional', 'bodies', 'but', 'as', 'president', 'ruto', 'returns', 'to', 'the', 'global', 'stage', 'the', 'big', 'question', 'remains', 'where', 'do', 'we', 'as', 'country', 'stand', 'in', 'today', 'version', 'of', 'the', 'cold', 'war', 'the', 'information', 'and', 'economic', 'war', 'between', 'china', 'and', 'russia', 'on', 'the', 'one', 'hand', 'and', 'the', 'us', 'and', 'its', 'allies', 'since', 'that', 'famous', 'statement', 'by', 'ambassador', 'martin', 'kimani', 'at', 'the', 'united', 'nations', 'security', 'council', 'can', 'we', 'still', 'claim', 'to', 'be', 'among', 'the', 'strongest', 'voices', 'in', 'africa', 'against', 'the', 'russian', 'illegal', 'aggression', 'against', 'ukraine', 'we', 'have', 'to', 'take', 'clear', 'and', 'strong', 'positions', 'because', 'we', 'are', 'in', 'the', 'middle', 'of', 'increasing', 'competition', 'for', 'geopolitical', 'and', 'geo', 'economics', 'global', 'dominance', 'today', 'the', 'us', 'company', 'starlink', 'has', 'emerged', 'ahead', 'after', 'launching', 'the', 'first', 'low', 'earth', 'orbit', 'satellite', 'leo', 'that', 'has', 'capability', 'to', 'provide', 'direct', 'to', 'device', 'communication', 'thereby', 'posing', 'big', 'threat', 'to', 'incumbent', 'mobile', 'network', 'operators', 'read', 'somewhere', 'how', 'china', 'is', 'also', 'prepping', 'its', 'own', 'expansive', 'and', 'major', 'leo', 'constellation', 'as', 'an', 'alternative', 'to', 'initiatives', 'from', 'us', 'europe', 'and', 'japan', 'the', 'predictions', 'right', 'now', 'are', 'that', 'china', 'and', 'russia', 'want', 'to', 'leverage', 'on', 'their', 'diplomatic', 'influence', 'and', 'relationships', 'in', 'africa', 'to', 'favour', 'the', 'entry', 'of', 'chinese', 'leo', 'operators', 'especially', 'when', 'it', 'comes', 'to', 'regulatory', 'market', 'access', 'the', 'competition', 'is', 'expected', 'to', 'be', 'stiff', 'because', 'africa', 'is', 'the', 'place', 'expected', 'to', 'produce', 'anticipated', 'future', 'revenues', 'for', 'most', 'leo', 'operators', 'stakes', 'are', 'even', 'higher', 'because', 'of', 'the', 'growing', 'two', 'fold', 'civilian', 'military', 'use', 'of', 'leo', 'kenya', 'and', 'indeed', 'africa', 'as', 'whole', 'must', 'take', 'firm', 'stand', 'and', 'speak', 'more', 'vociferously', 'on', 'the', 'prevailing', 'geopolitical', 'tensions', 'the', 'negative', 'impact', 'of', 'the', 'illegal', 'russian', 'invasion', 'of', 'ukraine', 'on', 'the', 'economies', 'of', 'the', 'continent', 'is', 'not', 'getting', 'adequate', 'articulation', 'in', 'international', 'fora', 'yet', 'many', 'countries', 'on', 'the', 'continen ...
# ['some', 'parents', 'have', 'managed', 'to', 'salvage', 'some', 'form', 'of', 'self', 'care', 'and', 'practice', 'it', 'on', 'budget', 'consider', 'all', 'your', 'sources', 'of', 'income', 'which', 'include', 'your', 'net', 'salary', 'and', 'the', 'income', 'from', 'your', 'side', 'hustle', 'premature', 'ejaculation', 'is', 'fairly', 'common', 'and', 'causes', 'lot', 'of', 'distress', 'but', 'things', 'are', 'made', 'worse', 'if', 'your', 'partner', 'is', 'unsupportive', 'the', 'loss', 'of', 'one', 'or', 'both', 'breasts', 'can', 'significantly', 'affect', 'woman', 'quality', 'of', 'life', 'do', 'not', 'wait', 'until', 'you', 'feel', 'lump', 'before', 'getting', 'screened', 'as', 'mammograms', 'can', 'detect', 'lumps', 'before', 'you', 'feel', 'them', 'breast', 'cancer', 'is', 'among', 'the', 'top', 'female', 'cancers', 'in', 'kenya', 'please', 'advise', 'me', 'on', 'how', 'to', 'invest', 'this', 'money', 'so', 'that', 'can', 'remain', 'financially', 'stable', 'for', 'life', 'recently', 'believed', 'that', 'wasn', 'doing', 'well', 'financially', 'because', 'don', 'pay', 'tithe', 'and', 'started', 'paying', 'but', 'am', 'still', 'not', 'improving', 'have', 'two', 'channels', 'where', 'save', 'money', 'in', 'bank', 'account', 'that', 'pays', 'rate', 'of', 'return', 'for', 'the', 'balance', 'held', 'and', 'in', 'money', 'market', 'fund', 'am', 'afraid', 'of', 'misusing', 'my', 'lump', 'sum', 'pension', 'the', 'thought', 'of', 'breaking', 'even', 'in', 'the', 'first', 'year', 'and', 'going', 'on', 'vacation', 'may', 'be', 'tempting', 'but', 'it', 'doesn', 'always', 'happen', 'that', 'quickly', 'after', 'quitting', 'athletics', 'due', 'to', 'injury', 'winnie', 'atieno', 'returned', 'to', 'her', 'other', 'passion', 'writing', 'more', 'balanced', 'approach', 'is', 'to', 'communicate', 'succession', 'plans', 'discreetly', 'within', 'the', 'management', 'team', 'while', 'also', 'providing', 'development', 'opportunities', 'for', 'potential', 'leaders', 'fund', 'the', 'land', 'purchase', 'through', 'investing', 'and', 'take', 'loan', 'to', 'finance', 'building', 'the', 'house', 'to', 'accomplish', 'both', 'goals', 'in', 'the', 'shortest', 'time', 'you', 'need', 'to', 'review', 'your', 'expenditure', 'the', 'mind', 'of', 'sex', 'addict', 'is', 'preoccupied', 'with', 'sexual
irituality', 'parenting', 'navigating', 'relationships', 'work', 'and', 'business', 'and', 'all', 'that', 'is', 'life', 'it', 'is', 'hosted', 'byamani', 'maranga', 'an', 'award', 'winning', 'podcaster', 'and', 'communications', 'specialist', 'come', 'thursday', 'masengeli', 'was', 'out', 'of', 'sight', 'from', 'the', 'public', 'eye', 'only', 'resurfacing', 'when', 'dp', 'gachagua', 'visited', 'the', 'police', 'stand', 'at', 'the', 'ask', 'show', 'family', 'of', 'murdered', 'olympian', 'blames', 'police', 'for', 'not', 'acting', 'swiftly', 'to', 'save', 'their', 'daughter', 'tsc', 'and', 'kuppet', 'say', 'they', 'have', 'agrees', 'to', 'settle', 'pending', 'matters', 'through', 'talks']

# %%
tokenized_sentences = [ gensim.utils.simple_preprocess(str(sentence), deacc = True) for sentence in df['paragraphs'].values ]

# %%
no_stopwords = [[word for word in sentence if word.lower() not in stopwords] for sentence in tokenized_sentences]

# %%
bigram = gensim.models.Phrases(no_stopwords, min_count=5, threshold=100)

# %%
bigram_phraser = Phraser(bigram)
bigrams = [bigram_phraser[sentence] for sentence in no_stopwords]

# %%
no_stopwords
# Out:
# [['purchases', 'pleaselog'],
#  ['daniel',
#   'mururu',
#   'accused',
#   'radicalisation',
#   'defiling',
#   'underage',
#   'girls',
#   'raping',
#   'women',
#   'daniel',
#   'mururu',
#   'accused',
#   'radicalisation',
#   'defiling',
#   'underage',
#   'girls',
#   'raping',
#   'women',
#   'senate',
#   'argues',
#   'high',
#   'court',
#   'order',
#   'violates',
#   'natural',
#   'justice',
#   'excluding',
#   'legislative',
#   'body',
#   'proceedings',
#   'pastor',
#   'bizarre',
#   'rituals',
#   'blood',
#   'sprinkling',
#   'forced',
#   'sexual',
#   'acts',
#   'pulpit',
#   'damaris',
#   'kathira',
#   'friends',
#   'planned',
#   'occasion',
#   'mark',
#   'new',
#   'chapter',
#   'lives',
#   'kenha',
#   'officials',
#   'outline',
#   'three',
#   'options',
#   'end',
#   'slaughter',
#   'killer',
#   'bridge',
#   'tharaka',
#   'nithi',
#   'van',
#   'part',
#   'convoy',
#   'carrying',
#   'group',
#   'friends',
#   'meru',
#   'parental',
#   'blessing',
#   'ceremony',
#   'four',
#   'victims',
#   'succumb',
#   'deep',
#   'machete',
#   'cuts',
#   'angry',
#   'villagers',
#   'beat',
#   'assailant',
#   'death',
#   'residents',
#   'accuse',
#   'pastor',
#   'engaging',
#   'activities',
#   'bordering',
#   'cultism',
#   'neighbours',
#   'tried',
#   'put',
#   'fire',
#   'strong',
#   'winds',
#   'made',
#   'inferno',
#   'spread',
#   'quickly',
#   'circumcision',
#   'one',
#   'important',
#   'ceremonies',
#   'area',
#   'communities',
#   'would',
#   'tragedy',
#   'averted',
#   'police',
#   'taken',
#   'seriously',
#   'complaints',
#   'family',
#   'kin',
#   'thief',
#   'living',
#   'fear',
#   'attacked',
#   'longer',
#   'safe',
#   'resident',
#   'said',
#   'mp',
#   'says',
#   'gachagua',
#   'aim',
#   'weaken',
#   'president',
#   'william',
#   'ruto',
#   'influence',
#   'mt',
#   'kenya',
#   'ordained',
#   'methodist',
#   'reverend',
#   'civil',
#   'servant',
#   'mr',
#   'mutuma',
#   'joined',
#   'politics',
#   'high',
#   'court',
#   'certifies',
#   'case',
#   'urgent',
#   'sets',
#   'mention',
#   'september'],
#  ['president',
#   'william',
#   'ruto',
#   'shakes',
#   'hands',
#   'chinese',
#   'president',
#   'xi',
#   'jinping',
#   'bilateral',
#   'talks',
#   'great',
#   'hall',
#   'people',
#   'beijing',
#   'september',
#   'byjaindi',
#   'kisero',
#   'former',
#   'nation',
#   'media',
#   'group',
#   'managing',
#   'editor',
#   'business',
#   'economic',
#   'affairs',
#   'president',
#   'william',
#   'ruto',
#   'back',
#   'global',
#   'stage',
#   'leading',
#   'large',
#   'delegation',
#   'china',
#   'attend',
#   'latest',
#   'version',
#   'forum',
#   'china',
#   'africa',
#   'cooperation',
#   'focac',
#   'china',
#   'important',
#   'us',
#   'month',
#   'july',
#   'year',
#   'alone',
#   'cough',
#   'whopping',
#   'sh',
#   'billion',
#   'repay',
#   'chinese',
#   'loans',
#   'impact',
#   'cash',
#   'flows',
#   'repayments',
#   'chinese',
#   'debts',
#   'come',
#   'months',
#   'july',
#   'january',
#   'government',
#   'literally',
#   'freezes',
#   'development',
#   'spending',
#   'think',
#   'exaggerating',
#   'download',
#   'latest',
#   'monthly',
#   'budget',
#   'outturn',
#   'published',
#   'regularly',
#   'national',
#   'treasury',
#   'repayment',
#   'chinese',
#   'loans',
#   'also',
#   'almost',
#   'crowding',
#   'exchequer',
#   'releases',
#   'pensions',
#   'constitutional',
#   'bodies',
#   'president',
#   'ruto',
#   'returns',
#   'global',
#   'stage',
#   'big',
#   'question',
#   'remains',
#   'country',
#   'stand',
#   'today',
#   'version',
#   'cold',
#   'war',
#   'information',
#   'economic',
#   'war',
#   'china',
#   'russia',
#   'one',
#   'hand',
#   'us',
#   'allies',
#   'since',
#   'famous',
#   'statement',
#   'ambassador',
#   'martin',
#   'kimani',
#   'united',
#   'nations',
#   'security',
#   'council',
#   'still',
#   'claim',
#   'among',
#   'strongest',
#   'voices',
#   'africa',
#   'russian',
#   'illegal',
#   'aggression',
#   'ukraine',
#   'take',
#   'clear',
#   'strong',
#   'positions',
#   'middle',
#   'increasing',
#   'competition',
#   'geopolitical',
#   'geo',
#   'economics',
#   'global',
#   'dominance',
#   'today',
#   'us',
#   'company',
#   'starlink',
#   'emerged',
#   'ahead',
#   'launching',
#   'first',
#   'low',
#   'earth',
#   'orbit',
#   'satellite',
#   'leo',
#   'capability',
#   'provide',
#   'direct',
#   'device',
#   'communication',
#   'thereby',
#   'posing',
#   'big',
#   'threat',
#   'incumbent',
#   'mobile',
#   'network',
#   'operators',
#   'read',
#   'somewhere',
#   'china',
#   'also',
#   'prepping',
#   'expansive',
#   'major',
#   'leo',
#   'constellation',
#   'alternative',
#   'initiatives',
#   'us',
#   'europe',
#   'japan',
#   'predictions',
#   'right',
#   'china',
#   'russia',
#   'want',
#   'leverage',
#   'diplomatic',
#   'influence',
#   'relationships',
#   'africa',
#   'favour',
#   'entry',
#   'chinese',
#   'leo',
#   'operators',
#   'especially',
#   'comes',
#   'regulatory',
#   'market',
#   'access',
#   'competition',
#   'expected',
#   'stiff',
#   'africa',
#   'place',
#   'expected',
#   'produce',
#   'anticipated',
#   'future',
#   'revenues',
#   'leo',
#   'operators',
#   'stakes',
#   'even',
#   'higher',
#   'growing',
#   'two',
#   'fold',
#   'civilian',
#   'military',
#   'use',
#   'leo',
#   'kenya',
#   'indeed',
#   'africa',
#   'whole',
#   'must',
#   'take',
#   'firm',
#   'stand',
#   'speak',
#   'vociferously',
#   'prevailing',
#   'geopolitical',
#   'tensions',
#   'negative',
#   'impact',
#   'illegal',
#   'russian',
#   'invasion',
#   'ukraine',
#   'economies',
#   'continent',
#   'getting',
#   'adequate',
#   'articulation',
#   'international',
#   'fora',
#   'yet',
#   'many',
#   'countries',
#   'continent',
#   'including',
#   'kenya',
#   'depend',
#   'heavily',
#   'two',
#   'countries',
#   'critical',
#   'food',
#   'imports',
#   'particularly',
#   'wheat',
#   'fertiliser',
#   'steel',
#   'according',
#   'africa',
#   'development',
#   'bank',
#   'continent',
#   'spends',
#   'billion',
#   'imports',
#   'million',
#   'tonnes',
#   'food',
#   'annually',
#   'indeed',
#   'war',
#   'continues',
#   'cause',
#   'disruption',
#   'world',
#   'due',
#   'fact',
#   'grain',
#   'exports',
#   'ukraine',
#   'vital',
#   'global',
#   'food',
#   'security',
#   'grain',
#   'markets',
#   'read',
#   'somewhere',
#   'russia',
#   'invasion',
#   'ukrainian',
#   'wheat',
#   'barley',
#   'exports',
#   'accounted',
#   'per',
#   'cent',
#   'respectively',
#   'global',
#   'supplies',
#   'disruption',
#   'exports',
#   'mitigated',
#   'fact',
#   'ukrainian',
#   'efforts',
#   'black',
#   'sea',
#   'secured',
#   'maritime',
#   'corridor',
#   'export',
#   'goods',
#   'black',
#   'sea',
#   'ports',
#   'war',
#   'ukraine',
#   'happening',
#   'context',
#   'economies',
#   'continent',
#   'experiencing',
#   'de',
#   'registering',
#   'low',
#   'manufacturing',
#   'gdp',
#   'ratios',
#   'conflict',
#   'also',
#   'bound',
#   'delay',
#   'decision',
#   'africa',
#   'debt',
#   'problems',
#   'currently',
#   'large',
#   'number',
#   'economies',
#   'continent',
#   'tottering',
#   'debt',
#   'cliff',
#   'edge',
#   'ethiopia',
#   'gone',
#   'painful',
#   'potentially',
#   'destabilising',
#   'debt',
#   'default',
#   'africa',
#   'third',
#   'debt',
#   'default',
#   'three',
#   'years',
#   'ghana',
#   'december',
#   'zambia',
#   'countries',
#   'forced',
#   'operate',
#   'context',
#   'downgraded',
#   'credit',
#   'ratings',
#   'consequently',
#   'increased',
#   'borrowing',
#   'costs',
#   'african',
#   'countries',
#   'borrowing',
#   'much',
#   'higher',
#   'cost',
#   'rest',
#   'world',
#   'president',
#   'ruto',
#   'returns',
#   'global',
#   'stage',
#   'navigating',
#   'increasingly',
#   'complex',
#   'international',
#   'relations',
#   'landscape',
#   'going',
#   'remain',
#   'big',
#   'challenge',
#   'two',
#   'years',
#   'ago',
#   'kenya',
#   'widely',
#   'criticised',
#   'swapping',
#   'russian',
#   'fertiliser',
#   'free',
#   'pass',
#   'war',
#   'ukraine',
#   'arrival',
#   'tonnes',
#   'fertiliser',
#   'moscow',
#   'sent',
#   'country',
#   'arrangement',
#   'facilitated',
#   'united',
#   'nations',
#   'point',
#   'seemed',
#   'kenya',
#   'taking',
#   'position',
#   'side',
#   'brics',
#   'initiative',
#   'encourages',
#   'settlement',
#   'international',
#   'trade',
#   'currencies',
#   'dollar',
#   'must',
#   'carefully',
#   'choose',
#   'want',
#   'russian',
#   'invasion',
#   'ukraine',
#   'one',
#   'biggest',
#   'sources',
#   'imported',
#   'inflation',
#   'macroeconomy',
#   'email',
#   'protected',
#   'kenya',
#   'put',
#   'money',
#   'laundering',
#   'grey',
#   'list',
#   'early',
#   'year',
#   'financial',
#   'action',
#   'task',
#   'force',
#   'start',
#   'aligning',
#   'state',
#   'departments',
#   'ministries',
#   'scrapping',
#   'politically',
#   'motivated',
#   'departments',
#   'come',
#   'always',
#   'looking',
#   'ways',
#   'improve',
#   'stories',
#   'let',
#   'us',
#   'know',
#   'liked',
#   'improve',
#   'ad',
#   'blocker',
#   'please',
#   'disable',
#   'reload',
#   'page',
#   'try',
#   'later',
#   'free'],
#  ['president',
#   'william',
#   'ruto',
#   'shakes',
#   'hands',
#   'chinese',
#   'president',
#   'xi',
#   'jinping',
#   'bilateral',
#   'talks',
#   'great',
#   'hall',
#   'people',
#   'beijing',
#   'september',
#   'byjaindi',
#   'kisero',
#   'former',
#   'nation',
#   'media',
#   'group',
#   'managing',
#   'editor',
#   'business',
#   'economic',
#   'affairs',
#   'president',
#   'william',
#   'ruto',
#   'back',
#   'global',
#   'stage',
#   'leading',
#   'large',
#   'delegation',
#   'china',
#   'attend',
#   'latest',
#   'version',
#   'forum',
#   'china',
#   'africa',
#   'cooperation',
#   'focac',
#   'china',
#   'important',
#   'us',
#   'month',
#   'july',
#   'year',
#   'alone',
#   'cough',
#   'whopping',
#   'sh',
#   'billion',
#   'repay',
#   'chinese',
#   'loans',
#   'impact',
#   'cash',
#   'flows',
#   'repayments',
#   'chinese',
#   'debts',
#   'come',
#   'months',
#   'july',
#   'january',
#   'government',
#   'literally',
#   'freezes',
#   'development',
#   'spending',
#   'think',
#   'exaggerating',
#   'download',
#   'latest',
#   'monthly',
#   'budget',
#   'outturn',
#   'published',
#   'regularly',
#   'national',
#   'treasury',
#   'repayment',
#   'chinese',
#   'loans',
#   'also',
#   'almost',
#   'crowding',
#   'exchequer',
#   'releases',
#   'pensions',
#   'constitutional',
#   'bodies',
#   'president',
#   'ruto',
#   'returns',
#   'global',
#   'stage',
#   'big',
#   'question',
#   'remains',
#   'country',
#   'stand',
#   'today',
#   'version',
#   'cold',
#   'war',
#   'information',
#   'economic',
#   'war',
#   'china',
#   'russia',
#   'one',
#   'hand',
#   'us',
#   'allies',
#   'since',
#   'famous',
#   'statement',
#   'ambassador',
#   'martin',
#   'kimani',
#   'united',
#   'nations',
#   'security',
#   'council',
#   'still',
#   'claim',
#   'among',
#   'strongest',
#   'voices',
#   'africa',
#   'russian',
#   'illegal',
#   'aggression',
#   'ukraine',
#   'take',
#   'clear',
#   'strong',
#   'positions',
#   'middle',
#   'increasing',
#   'competition',
#   'geopolitical',
#   'geo',
#   'economics',
#   'global',
#   'dominance',
#   'today',
#   'us',
#   'company',
#   'starlink',
#   'emerged',
#   'ahead',
#   'launching',
#   'first',
#   'low',
#   'earth',
#   'orbit',
#   'satellite',
#   'leo',
#   'capability',
#   'provide',
#   'direct',
#   'device',
#   'communication',
#   'thereby',
#   'posing',
#   'big',
#   'threat',
#   'incumbent',
#   'mobile',
#   'network',
#   'operators',
#   'read',
#   'somewhere',
#   'china',
#   'also',
#   'prepping',
#   'expansive',
#   'major',
#   'leo',
#   'constellation',
#   'alternative',
#   'initiatives',
#   'us',
#   'europe',
#   'japan',
#   'predictions',
#   'right',
#   'china',
#   'russia',
#   'want',
#   'leverage',
#   'diplomatic',
#   'influence',
#   'relationships',
#   'africa',
#   'favour',
#   'entry',
#   'chinese',
#   'leo',
#   'operators',
#   'especially',
#   'comes',
#   'regulatory',
#   'market',
#   'access',
#   'competition',
#   'expected',
#   'stiff',
#   'africa',
#   'place',
#   'expected',
#   'produce',
#   'anticipated',
#   'future',
#   'revenues',
#   'leo',
#   'operators',
#   'stakes',
#   'even',
#   'higher',
#   'growing',
#   'two',
#   'fold',
#   'civilian',
#   'military',
#   'use',
#   'leo',
#   'kenya',
#   'indeed',
#   'africa',
#   'whole',
#   'must',
#   'take',
#   'firm',
#   'stand',
#   'speak',
#   'vociferously',
#   'prevailing',
#   'geopolitical',
#   'tensions',
#   'negative',
#   'impact',
#   'illegal',
#   'russian',
#   'invasion',
#   'ukraine',
#   'economies',
#   'continent',
#   'getting',
#   'adequate',
#   'articulation',
#   'international',
#   'fora',
#   'yet',
#   'many',
#   'countries',
#   'continent',
#   'including',
#   'kenya',
#   'depend',
#   'heavily',
#   'two',
#   'countries',
#   'critical',
#   'food',
#   'imports',
#   'particularly',
#   'wheat',
#   'fertiliser',
#   'steel',
#   'according',
#   'africa',
#   'development',
#   'bank',
#   'continent',
#   'spends',
#   'billion',
#   'imports',
#   'million',
#   'tonnes',
#   'food',
#   'annually',
#   'indeed',
#   'war',
#   'continues',
#   'cause',
#   'disruption',
#   'world',
#   'due',
#   'fact',
#   'grain',
#   'exports',
#   'ukraine',
#   'vital',
#   'global',
#   'food',
#   'security',
#   'grain',
#   'markets',
#   'read',
#   'somewhere',
#   'russia',
#   'invasion',
#   'ukrainian',
#   'wheat',
#   'barley',
#   'exports',
#   'accounted',
#   'per',
#   'cent',
#   'respectively',
#   'global',
#   'supplies',
#   'disruption',
#   'exports',
#   'mitigated',
#   'fact',
#   'ukrainian',
#   'efforts',
#   'black',
#   'sea',
#   'secured',
#   'maritime',
#   'corridor',
#   'export',
#   'goods',
#   'black',
#   'sea',
#   'ports',
#   'war',
#   'ukraine',
#   'happening',
#   'context',
#   'economies',
#   'continent',
#   'experiencing',
#   'de',
#   'registering',
#   'low',
#   'manufacturing',
#   'gdp',
#   'ratios',
#   'conflict',
#   'also',
#   'bound',
#   'delay',
#   'decision',
#   'africa',
#   'debt',
#   'problems',
#   'currently',
#   'large',
#   'number',
#   'economies',
#   'continent',
#   'tottering',
#   'debt',
#   'cliff',
#   'edge',
#   'ethiopia',
#   'gone',
#   'painful',
#   'potentially',
#   'destabilising',
#   'debt',
#   'default',
#   'africa',
#   'third',
#   'debt',
#   'default',
#   'three',
#   'years',
#   'ghana',
#   'december',
#   'zambia',
#   'countries',
#   'forced',
#   'operate',
#   'context',
#   'downgraded',
#   'credit',
#   'ratings',
#   'consequently',
#   'increased',
#   'borrowing',
#   'costs',
#   'african',
#   'countries',
#   'borrowing',
#   'much',
#   'higher',
#   'cost',
#   'rest',
#   'world',
#   'president',
#   'ruto',
#   'returns',
#   'global',
#   'stage',
#   'navigating',
#   'increasingly',
#   'complex',
#   'international',
#   'relations',
#   'landscape',
#   'going',
#   'remain',
#   'big',
#   'challenge',
#   'two',
#   'years',
#   'ago',
#   'kenya',
#   'widely',
#   'criticised',
#   'swapping',
#   'russian',
#   'fertiliser',
#   'free',
#   'pass',
#   'war',
#   'ukraine',
#   'arrival',
#   'tonnes',
#   'fertiliser',
#   'moscow',
#   'sent',
#   'country',
#   'arrangement',
#   'facilitated',
#   'united',
#   'nations',
#   'point',
#   'seemed',
#   'kenya',
#   'taking',
#   'position',
#   'side',
#   'brics',
#   'initiative',
#   'encourages',
#   'settlement',
#   'international',
#   'trade',
#   'currencies',
#   'dollar',
#   'must',
#   'carefully',
#   'choose',
#   'want',
#   'russian',
#   'invasion',
#   'ukraine',
#   'one',
#   'biggest',
#   'sources',
#   'imported',
#   'inflation',
#   'macroeconomy',
#   'email',
#   'protected',
#   'kenya',
#   'put',
#   'money',
#   'laundering',
#   'grey',
#   'list',
#   'early',
#   'year',
#   'financial',
#   'action',
#   'task',
#   'force',
#   'start',
#   'aligning',
#   'state',
#   'departments',
#   'ministries',
#   'scrapping',
#   'politically',
#   'motivated',
#   'departments',
#   'come',
#   'always',
#   'looking',
#   'ways',
#   'improve',
#   'stories',
#   'let',
#   'us',
#   'know',
#   'liked',
#   'improve',
#   'ad',
#   'blocker',
#   'please',
#   'disable',
#   'reload',
#   'page',
#   'try',
#   'later',
#   'free'],
#  ['president',
#   'william',
#   'ruto',
#   'shakes',
#   'hands',
#   'chinese',
#   'president',
#   'xi',
#   'jinping',
#   'bilateral',
#   'talks',
#   'great',
#   'hall',
#   'people',
#   'beijing',
#   'september',
#   'byjaindi',
#   'kisero',
#   'former',
#   'nation',
#   'media',
#   'group',
#   'managing',
#   'editor',
#   'business',
#   'economic',
#   'affairs',
#   'president',
#   'william',
#   'ruto',
#   'back',
#   'global',
#   'stage',
#   'leading',
#   'large',
#   'delegation',
#   'china',
#   'attend',
#   'latest',
#   'version',
#   'forum',
#   'china',
#   'africa',
#   'cooperation',
#   'focac',
#   'china',
#   'important',
#   'us',
#   'month',
#   'july',
#   'year',
#   'alone',
#   'cough',
#   'whopping',
#   'sh',
#   'billion',
#   'repay',
#   'chinese',
#   'loans',
#   'impact',
#   'cash',
#   'flows',
#   'repayments',
#   'chinese',
#   'debts',
#   'come',
#   'months',
#   'july',
#   'january',
#   'government',
#   'literally',
#   'freezes',
#   'development',
#   'spending',
#   'think',
#   'exaggerating',
#   'download',
#   'latest',
#   'monthly',
#   'budget',
#   'outturn',
#   'published',
#   'regularly',
#   'national',
#   'treasury',
#   'repayment',
#   'chinese',
#   'loans',
#   'also',
#   'almost',
#   'crowding',
#   'exchequer',
#   'releases',
#   'pensions',
#   'constitutional',
#   'bodies',
#   'president',
#   'ruto',
#   'returns',
#   'global',
#   'stage',
#   'big',
#   'question',
#   'remains',
#   'country',
#   'stand',
#   'today',
#   'version',
#   'cold',
#   'war',
#   'information',
#   'economic',
#   'war',
#   'china',
#   'russia',
#   'one',
#   'hand',
#   'us',
#   'allies',
#   'since',
#   'famous',
#   'statement',
#   'ambassador',
#   'martin',
#   'kimani',
#   'united',
#   'nations',
#   'security',
#   'council',
#   'still',
#   'claim',
#   'among',
#   'strongest',
#   'voices',
#   'africa',
#   'russian',
#   'illegal',
#   'aggression',
#   'ukraine',
#   'take',
#   'clear',
#   'strong',
#   'positions',
#   'middle',
#   'increasing',
#   'competition',
#   'geopolitical',
#   'geo',
#   'economics',
#   'global',
#   'dominance',
#   'today',
#   'us',
#   'company',
#   'starlink',
#   'emerged',
#   'ahead',
#   'launching',
#   'first',
#   'low',
#   'earth',
#   'orbit',
#   'satellite',
#   'leo',
#   'capability',
#   'provide',
#   'direct',
#   'device',
#   'communication',
#   'thereby',
#   'posing',
#   'big',
#   'threat',
#   'incumbent',
#   'mobile',
#   'network',
#   'operators',
#   'read',
#   'somewhere',
#   'china',
#   'also',
#   'prepping',
#   'expansive',
#   'major',
#   'leo',
#   'constellation',
#   'alternative',
#   'initiatives',
#   'us',
#   'europe',
#   'japan',
#   'predictions',
#   'right',
#   'china',
#   'russia',
#   'want',
#   'leverage',
#   'diplomatic',
#   'influence',
#   'relationships',
#   'africa',
#   'favour',
#   'entry',
#   'chinese',
#   'leo',
#   'operators',
#   'especially',
#   'comes',
#   'regulatory',
#   'market',
#   'access',
#   'competition',
#   'expected',
#   'stiff',
#   'africa',
#   'place',
#   'expected',
#   'produce',
#   'anticipated',
#   'future',
#   'revenues',
#   'leo',
#   'operators',
#   'stakes',
#   'even',
#   'higher',
#   'growing',
#   'two',
#   'fold',
#   'civilian',
#   'military',
#   'use',
#   'leo',
#   'kenya',
#   'indeed',
#   'africa',
#   'whole',
#   'must',
#   'take',
#   'firm',
#   'stand',
#   'speak',
#   'vociferously',
#   'prevailing',
#   'geopolitical',
#   'tensions',
#   'negative',
#   'impact',
#   'illegal',
#   'russian',
#   'invasion',
#   'ukraine',
#   'economies',
#   'continent',
#   'getting',
#   'adequate',
#   'articulation',
#   'international',
#   'fora',
#   'yet',
#   'many',
#   'countries',
#   'continent',
#   'including',
#   'kenya',
#   'depend',
#   'heavily',
#   'two',
#   'countries',
#   'critical',
#   'food',
#   'imports',
#   'particularly',
#   'wheat',
#   'fertiliser',
#   'steel',
#   'according',
#   'africa',
#   'development',
#   'bank',
#   'continent',
#   'spends',
#   'billion',
#   'imports',
#   'million',
#   'tonnes',
#   'food',
#   'annually',
#   'indeed',
#   'war',
#   'continues',
#   'cause',
#   'disruption',
#   'world',
#   'due',
#   'fact',
#   'grain',
#   'exports',
#   'ukraine',
#   'vital',
#   'global',
#   'food',
#   'security',
#   'grain',
#   'markets',
#   'read',
#   'somewhere',
#   'russia',
#   'invasion',
#   'ukrainian',
#   'wheat',
#   'barley',
#   'exports',
#   'accounted',
#   'per',
#   'cent',
#   'respectively',
#   'global',
#   'supplies',
#   'disruption',
#   'exports',
#   'mitigated',
#   'fact',
#   'ukrainian',
#   'efforts',
#   'black',
#   'sea',
#   'secured',
#   'maritime',
#   'corridor',
#   'export',
#   'goods',
#   'black',
#   'sea',
#   'ports',
#   'war',
#   'ukraine',
#   'happening',
#   'context',
#   'economies',
#   'continent',
#   'experiencing',
#   'de',
#   'registering',
#   'low',
#   'manufacturing',
#   'gdp',
#   'ratios',
#   'conflict',
#   'also',
#   'bound',
#   'delay',
#   'decision',
#   'africa',
#   'debt',
#   'problems',
#   'currently',
#   'large',
#   'number',
#   'economies',
#   'continent',
#   'tottering',
#   'debt',
#   'cliff',
#   'edge',
#   'ethiopia',
#   'gone',
#   'painful',
#   'potentially',
#   'destabilising',
#   'debt',
#   'default',
#   'africa',
#   'third',
#   'debt',
#   'default',
#   'three',
#   'years',
#   'ghana',
#   'december',
#   'zambia',
#   'countries',
#   'forced',
#   'operate',
#   'context',
#   'downgraded',
#   'credit',
#   'ratings',
#   'consequently',
#   'increased',
#   'borrowing',
#   'costs',
#   'african',
#   'countries',
#   'borrowing',
#   'much',
#   'higher',
#   'cost',
#   'rest',
#   'world',
#   'president',
#   'ruto',
#   'returns',
#   'global',
#   'stage',
#   'navigating',
#   'increasingly',
#   'complex',
#   'international',
#   'relations',
#   'landscape',
#   'going',
#   'remain',
#   'big',
#   'challenge',
#   'two',
#   'years',
#   'ago',
#   'kenya',
#   'widely',
#   'criticised',
#   'swapping',
#   'russian',
#   'fertiliser',
#   'free',
#   'pass',
#   'war',
#   'ukraine',
#   'arrival',
#   'tonnes',
#   'fertiliser',
#   'moscow',
#   'sent',
#   'country',
#   'arrangement',
#   'facilitated',
#   'united',
#   'nations',
#   'point',
#   'seemed',
#   'kenya',
#   'taking',
#   'position',
#   'side',
#   'brics',
#   'initiative',
#   'encourages',
#   'settlement',
#   'international',
#   'trade',
#   'currencies',
#   'dollar',
#   'must',
#   'carefully',
#   'choose',
#   'want',
#   'russian',
#   'invasion',
#   'ukraine',
#   'one',
#   'biggest',
#   'sources',
#   'imported',
#   'inflation',
#   'macroeconomy',
#   'email',
#   'protected',
#   'kenya',
#   'put',
#   'money',
#   'laundering',
#   'grey',
#   'list',
#   'early',
#   'year',
#   'financial',
#   'action',
#   'task',
#   'force',
#   'start',
#   'aligning',
#   'state',
#   'departments',
#   'ministries',
#   'scrapping',
#   'politically',
#   'motivated',
#   'departments',
#   'come',
#   'always',
#   'looking',
#   'ways',
#   'improve',
#   'stories',
#   'let',
#   'us',
#   'know',
#   'liked',
#   'improve',
#   'ad',
#   'blocker',
#   'please',
#   'disable',
#   'reload',
#   'page',
#   'try',
#   'later',
#   'free'],
#  ['president',
#   'william',
#   'ruto',
#   'shakes',
#   'hands',
#   'chinese',
#   'president',
#   'xi',
#   'jinping',
#   'bilateral',
#   'talks',
#   'great',
#   'hall',
#   'people',
#   'beijing',
#   'september',
#   'byjaindi',
#   'kisero',
#   'former',
#   'nation',
#   'media',
#   'group',
#   'managing',
#   'editor',
#   'business',
#   'economic',
#   'affairs',
#   'president',
#   'william',
#   'ruto',
#   'back',
#   'global',
#   'stage',
#   'leading',
#   'large',
#   'delegation',
#   'china',
#   'attend',
#   'latest',
#   'version',
#   'forum',
#   'china',
#   'africa',
#   'cooperation',
#   'focac',
#   'china',
#   'important',
#   'us',
#   'month',
#   'july',
#   'year',
#   'alone',
#   'cough',
#   'whopping',
#   'sh',
#   'billion',
#   'repay',
#   'chinese',
#   'loans',
#   'impact',
#   'cash',
#   'flows',
#   'repayments',
#   'chinese',
#   'debts',
#   'come',
#   'months',
#   'july',
#   'january',
#   'government',
#   'literally',
#   'freezes',
#   'development',
#   'spending',
#   'think',
#   'exaggerating',
#   'download',
#   'latest',
#   'monthly',
#   'budget',
#   'outturn',
#   'published',
#   'regularly',
#   'national',
#   'treasury',
#   'repayment',
#   'chinese',
#   'loans',
#   'also',
#   'almost',
#   'crowding',
#   'exchequer',
#   'releases',
#   'pensions',
#   'constitutional',
#   'bodies',
#   'president',
#   'ruto',
#   'returns',
#   'global',
#   'stage',
#   'big',
#   'question',
#   'remains',
#   'country',
#   'stand',
#   'today',
#   'version',
#   'cold',
#   'war',
#   'information',
#   'economic',
#   'war',
#   'china',
#   'russia',
#   'one',
#   'hand',
#   'us',
#   'allies',
#   'since',
#   'famous',
#   'statement',
#   'ambassador',
#   'martin',
#   'kimani',
#   'united',
#   'nations',
#   'security',
#   'council',
#   'still',
#   'claim',
#   'among',
#   'strongest',
#   'voices',
#   'africa',
#   'russian',
#   'illegal',
#   'aggression',
#   'ukraine',
#   'take',
#   'clear',
#   'strong',
#   'positions',
#   'middle',
#   'increasing',
#   'competition',
#   'geopolitical',
#   'geo',
#   'economics',
#   'global',
#   'dominance',
#   'today',
#   'us',
#   'company',
#   'starlink',
#   'emerged',
#   'ahead',
#   'launching',
#   'first',
#   'low',
#   'earth',
#   'orbit',
#   'satellite',
#   'leo',
#   'capability',
#   'provide',
#   'direct',
#   'device',
#   'communication',
#   'thereby',
#   'posing',
#   'big',
#   'threat',
#   'incumbent',
#   'mobile',
#   'network',
#   'operators',
#   'read',
#   'somewhere',
#   'china',
#   'also',
#   'prepping',
#   'expansive',
#   'major',
#   'leo',
#   'constellation',
#   'alternative',
#   'initiatives',
#   'us',
#   'europe',
#   'japan',
#   'predictions',
#   'right',
#   'china',
#   'russia',
#   'want',
#   'leverage',
#   'diplomatic',
#   'influence',
#   'relationships',
#   'africa',
#   'favour',
#   'entry',
#   'chinese',
#   'leo',
#   'operators',
#   'especially',
#   'comes',
#   'regulatory',
#   'market',
#   'access',
#   'competition',
#   'expected',
#   'stiff',
#   'africa',
#   'place',
#   'expected',
#   'produce',
#   'anticipated',
#   'future',
#   'revenues',
#   'leo',
#   'operators',
#   'stakes',
#   'even',
#   'higher',
#   'growing',
#   'two',
#   'fold',
#   'civilian',
#   'military',
#   'use',
#   'leo',
#   'kenya',
#   'indeed',
#   'africa',
#   'whole',
#   'must',
#   'take',
#   'firm',
#   'stand',
#   'speak',
#   'vociferously',
#   'prevailing',
#   'geopolitical',
#   'tensions',
#   'negative',
#   'impact',
#   'illegal',
#   'russian',
#   'invasion',
#   'ukraine',
#   'economies',
#   'continent',
#   'getting',
#   'adequate',
#   'articulation',
#   'international',
#   'fora',
#   'yet',
#   'many',
#   'countries',
#   'continent',
#   'including',
#   'kenya',
#   'depend',
#   'heavily',
#   'two',
#   'countries',
#   'critical',
#   'food',
#   'imports',
#   'particularly',
#   'wheat',
#   'fertiliser',
#   'steel',
#   'according',
#   'africa',
#   'development',
#   'bank',
#   'continent',
#   'spends',
#   'billion',
#   'imports',
#   'million',
#   'tonnes',
#   'food',
#   'annually',
#   'indeed',
#   'war',
#   'continues',
#   'cause',
#   'disruption',
#   'world',
#   'due',
#   'fact',
#   'grain',
#   'exports',
#   'ukraine',
#   'vital',
#   'global',
#   'food',
#   'security',
#   'grain',
#   'markets',
#   'read',
#   'somewhere',
#   'russia',
#   'invasion',
#   'ukrainian',
#   'wheat',
#   'barley',
#   'exports',
#   'accounted',
#   'per',
#   'cent',
#   'respectively',
#   'global',
#   'supplies',
#   'disruption',
#   'exports',
#   'mitigated',
#   'fact',
#   'ukrainian',
#   'efforts',
#   'black',
#   'sea',
#   'secured',
#   'maritime',
#   'corridor',
#   'export',
#   'goods',
#   'black',
#   'sea',
#   'ports',
#   'war',
#   'ukraine',
#   'happening',
#   'context',
#   'economies',
#   'continent',
#   'experiencing',
#   'de',
#   'registering',
#   'low',
#   'manufacturing',
#   'gdp',
#   'ratios',
#   'conflict',
#   'also',
#   'bound',
#   'delay',
#   'decision',
#   'africa',
#   'debt',
#   'problems',
#   'currently',
#   'large',
#   'number',
#   'economies',
#   'continent',
#   'tottering',
#   'debt',
#   'cliff',
#   'edge',
#   'ethiopia',
#   'gone',
#   'painful',
#   'potentially',
#   'destabilising',
#   'debt',
#   'default',
#   'africa',
#   'third',
#   'debt',
#   'default',
#   'three',
#   'years',
#   'ghana',
#   'december',
#   'zambia',
#   'countries',
#   'forced',
#   'operate',
#   'context',
#   'downgraded',
#   'credit',
#   'ratings',
#   'consequently',
#   'increased',
#   'borrowing',
#   'costs',
#   'african',
#   'countries',
#   'borrowing',
#   'much',
#   'higher',
#   'cost',
#   'rest',
#   'world',
#   'president',
#   'ruto',
#   'returns',
#   'global',
#   'stage',
#   'navigating',
#   'increasingly',
#   'complex',
#   'international',
#   'relations',
#   'landscape',
#   'going',
#   'remain',
#   'big',
#   'challenge',
#   'two',
#   'years',
#   'ago',
#   'kenya',
#   'widely',
#   'criticised',
#   'swapping',
#   'russian',
#   'fertiliser',
#   'free',
#   'pass',
#   'war',
#   'ukraine',
#   'arrival',
#   'tonnes',
#   'fertiliser',
#   'moscow',
#   'sent',
#   'country',
#   'arrangement',
#   'facilitated',
#   'united',
#   'nations',
#   'point',
#   'seemed',
#   'kenya',
#   'taking',
#   'position',
#   'side',
#   'brics',
#   'initiative',
#   'encourages',
#   'settlement',
#   'international',
#   'trade',
#   'currencies',
#   'dollar',
#   'must',
#   'carefully',
#   'choose',
#   'want',
#   'russian',
#   'invasion',
#   'ukraine',
#   'one',
#   'biggest',
#   'sources',
#   'imported',
#   'inflation',
#   'macroeconomy',
#   'email',
#   'protected',
#   'kenya',
#   'put',
#   'money',
#   'laundering',
#   'grey',
#   'list',
#   'early',
#   'year',
#   'financial',
#   'action',
#   'task',
#   'force',
#   'start',
#   'aligning',
#   'state',
#   'departments',
#   'ministries',
#   'scrapping',
#   'politically',
#   'motivated',
#   'departments',
#   'come',
#   'always',
#   'looking',
#   'ways',
#   'improve',
#   'stories',
#   'let',
#   'us',
#   'know',
#   'liked',
#   'improve',
#   'ad',
#   'blocker',
#   'please',
#   'disable',
#   'reload',
#   'page',
#   'try',
#   'later',
#   'free'],
#  ['parents',
#   'managed',
#   'salvage',
#   'form',
#   'self',
#   'care',
#   'practice',
#   'budget',
#   'consider',
#   'sources',
#   'income',
#   'include',
#   'net',
#   'salary',
#   'income',
#   'side',
#   'hustle',
#   'premature',
#   'ejaculation',
#   'fairly',
#   'common',
#   'causes',
#   'lot',
#   'distress',
#   'things',
#   'made',
#   'worse',
#   'partner',
#   'unsupportive',
#   'loss',
#   'one',
#   'breasts',
#   'significantly',
#   'affect',
#   'woman',
#   'quality',
#   'life',
#   'wait',
#   'feel',
#   'lump',
#   'getting',
#   'screened',
#   'mammograms',
#   'detect',
#   'lumps',
#   'feel',
#   'breast',
#   'cancer',
#   'among',
#   'top',
#   'female',
#   'cancers',
#   'kenya',
#   'please',
#   'advise',
#   'invest',
#   'money',
#   'remain',
#   'financially',
#   'stable',
#   'life',
#   'recently',
#   'believed',
#   'well',
#   'financially',
#   'pay',
#   'tithe',
#   'started',
#   'paying',
#   'still',
#   'improving',
#   'two',
#   'channels',
#   'save',
#   'money',
#   'bank',
#   'account',
#   'pays',
#   'rate',
#   'return',
#   'balance',
#   'held',
#   'money',
#   'market',
#   'fund',
#   'afraid',
#   'misusing',
#   'lump',
#   'sum',
#   'pension',
#   'thought',
#   'breaking',
#   'even',
#   'first',
#   'year',
#   'going',
#   'vacation',
#   'may',
#   'tempting',
#   'always',
#   'happen',
#   'quickly',
#   'quitting',
#   'athletics',
#   'due',
#   'injury',
#   'winnie',
#   'atieno',
#   'returned',
#   'passion',
#   'writing',
#   'balanced',
#   'approach',
#   'communicate',
#   'succession',
#   'plans',
#   'discreetly',
#   'within',
#   'management',
#   'team',
#   'also',
#   'providing',
#   'development',
#   'opportunities',
#   'potential',
#   'leaders',
#   'fund',
#   'land',
#   'purchase',
#   'investing',
#   'take',
#   'loan',
#   'finance',
#   'building',
#   'house',
#   'accomplish',
#   'goals',
#   'shortest',
#   'time',
#   'need',
#   'review',
#   'expenditure',
#   'mind',
#   'sex',
#   'addict',
#   'preoccupied',
#   'sexual',
#   'thoughts',
#   'extent',
#   'interferes',
#   'daily',
#   'work',
#   'relationships',
#   'culture',
#   'expected',
#   'look',
#   'fat',
#   'overweight',
#   'outrightly',
#   'obese',
#   'protruding',
#   'belly',
#   'must',
#   'boniface',
#   'osano',
#   'adjusting',
#   'accordingly',
#   'changing',
#   'living',
#   'standards',
#   'think',
#   'moving',
#   'leafy',
#   'address',
#   'less',
#   'costly',
#   'one',
#   'transferring',
#   'children',
#   'private',
#   'public',
#   'schools',
#   'admirable',
#   'determination',
#   'inspiring',
#   'passion',
#   'sport',
#   'youngster',
#   'seems',
#   'firmly',
#   'way',
#   'zenith',
#   'game',
#   'already',
#   'boasts',
#   'number',
#   'one',
#   'seed',
#   'tennis',
#   'region',
#   'kabura',
#   'cecilia',
#   'team',
#   'leader',
#   'founder',
#   'vitapharm',
#   'cosmetics',
#   'vitapharm',
#   'aesthetics',
#   'skin',
#   'care',
#   'solutions',
#   'skin',
#   'care',
#   'consultations',
#   'business',
#   'located',
#   'nairobi',
#   'important',
#   'consider',
#   'risk',
#   'profile',
#   'timeframe',
#   'investment',
#   'focus',
#   'investments',
#   'additional',
#   'savings',
#   'crucial',
#   'build',
#   'emergency',
#   'fund'],
#  ['certain',
#   'hpv',
#   'strains',
#   'cause',
#   'cancers',
#   'throat',
#   'anus',
#   'penis',
#   'cervix',
#   'among',
#   'others',
#   'say',
#   'life',
#   'give',
#   'manual',
#   'mother',
#   'sometimes',
#   'better',
#   'manual',
#   'toxic',
#   'mother',
#   'hard',
#   'truth',
#   'take',
#   'narrated',
#   'episode',
#   'life',
#   'craft',
#   'podcast',
#   'final',
#   'episode',
#   'season',
#   'jackie',
#   'mitchelle',
#   'take',
#   'trip',
#   'memory',
#   'lane',
#   'unravel',
#   'season',
#   'julius',
#   'yego',
#   'finished',
#   'th',
#   'javelin',
#   'finals',
#   'season',
#   'best',
#   'talks',
#   'sports',
#   'journalist',
#   'elias',
#   'makori',
#   'experience',
#   'land',
#   'prices',
#   'lucrative',
#   'nodes',
#   'riverside',
#   'upperhill',
#   'contracted',
#   'last',
#   'five',
#   'years',
#   'cas',
#   'appointed',
#   'president',
#   'recommendation',
#   'psc',
#   'death',
#   'penalty',
#   'mean',
#   'kenya',
#   'episode',
#   'listen',
#   'tales',
#   'africa',
#   'africans',
#   'voices',
#   'tell',
#   'story',
#   'different',
#   'parts',
#   'continent',
#   'episode',
#   'sport',
#   'interrogate',
#   'intrigues',
#   'state',
#   'kenyan',
#   'volleyball',
#   'benson',
#   'kipruto',
#   'named',
#   'final',
#   'marathon',
#   'squad',
#   'paris',
#   'olympics',
#   'hear',
#   'story',
#   'athlete',
#   'shopkeeper',
#   'episode',
#   'roselyn',
#   'obala',
#   'oliver',
#   'mathenge',
#   'patrick',
#   'langat',
#   'delve',
#   'kenya',
#   'political',
#   'scene',
#   'following',
#   'raila',
#   'official',
#   'candidacy',
#   'chairperson',
#   'auc',
#   'join',
#   'us',
#   'embark',
#   'journey',
#   'understand',
#   'impacts',
#   'noise',
#   'nuisance',
#   'lives',
#   'residents',
#   'explore',
#   'potential',
#   'solutions',
#   'fostering',
#   'harmony',
#   'urban',
#   'environments',
#   'episode',
#   'dive',
#   'world',
#   'laws',
#   'specifically',
#   'focusing',
#   'good',
#   'son',
#   'law',
#   'navigating',
#   'unique',
#   'relationship',
#   'challenging',
#   'right',
#   'approach',
#   'despite',
#   'increasing',
#   'awareness',
#   'mental',
#   'health',
#   'issues',
#   'remains',
#   'significant',
#   'stigma',
#   'attached',
#   'therapy',
#   'particularly',
#   'among',
#   'men',
#   'need',
#   'build',
#   'evidence',
#   'cultivate',
#   'confidence',
#   'entails',
#   'postgraduate',
#   'degree',
#   'starting',
#   'business',
#   'investing',
#   'could',
#   'something',
#   'hopeful',
#   'promising',
#   'turn',
#   'painful',
#   'cause',
#   'much',
#   'despair',
#   'epsiode',
#   'set',
#   'stage',
#   'black',
#   'gold',
#   'promised',
#   'turkana',
#   'people',
#   'refused',
#   'materialise',
#   'narrative',
#   'podcast',
#   'series',
#   'natural',
#   'justice',
#   'follow',
#   'individuals',
#   'communities',
#   'forced',
#   'frontline',
#   'conflict',
#   'push',
#   'back',
#   'using',
#   'kenyan',
#   'courts',
#   'preserve',
#   'dignity',
#   'brian',
#   'ogola',
#   'plays',
#   'cyrus',
#   'second',
#   'family',
#   'show',
#   'showmax',
#   'talks',
#   'character',
#   'building',
#   'makes',
#   'show',
#   'great',
#   'telenovela',
#   'hosts',
#   'barrack',
#   'bukusi',
#   'judy',
#   'karumbu',
#   'episode',
#   'hosts',
#   'barrack',
#   'judy',
#   'sit',
#   'second',
#   'family',
#   'cast',
#   'brian',
#   'venessa',
#   'explore',
#   'story',
#   'joel',
#   'cindy',
#   'played',
#   'brian',
#   'venessa',
#   'respectively',
#   'captivating',
#   'episode',
#   'story',
#   'behind',
#   'showmax',
#   'second',
#   'family',
#   'hosts',
#   'barrack',
#   'judy',
#   'joined',
#   'special',
#   'guests',
#   'charismatic',
#   'lead',
#   'actress',
#   'dora',
#   'nyaboke',
#   'plays',
#   'main',
#   'gain',
#   'valuable',
#   'insights',
#   'dynamic',
#   'landscape',
#   'retirement',
#   'options',
#   'learn',
#   'navigate',
#   'complexities',
#   'ensuring',
#   'secure',
#   'fulfilling',
#   'future',
#   'listen',
#   'john',
#   'ndua',
#   'investment',
#   'associate',
#   'public',
#   'markets',
#   'genghis',
#   'capital',
#   'kennedy',
#   'keli',
#   'general',
#   'manager',
#   'charge',
#   'pension',
#   'business',
#   'liaison',
#   'group',
#   'explore',
#   'intricacies',
#   'anita',
#   'soina',
#   'discusses',
#   'role',
#   'youth',
#   'africa',
#   'climate',
#   'summit',
#   'taking',
#   'place',
#   'nairobi',
#   'kenya',
#   'cryptocurrency',
#   'become',
#   'global',
#   'phenomenon',
#   'often',
#   'seem',
#   'complex',
#   'intimidating',
#   'newcomers',
#   'country',
#   'gamblers',
#   'counts',
#   'true',
#   'human',
#   'cost',
#   'gambling',
#   'bogonko',
#   'bosire',
#   'went',
#   'missing',
#   'september',
#   'disappeared',
#   'icc',
#   'cases',
#   'president',
#   'uhuru',
#   'kenyatta',
#   'deputy',
#   'william',
#   'ruto',
#   'hitting',
#   'crescendo',
#   'world',
#   'rally',
#   'championship',
#   'drew',
#   'positive',
#   'negative',
#   'headlines',
#   'event',
#   'major',
#   'tourist',
#   'attraction',
#   'eons',
#   'year',
#   'different',
#   'president',
#   'ruto',
#   'recent',
#   'lurking',
#   'attacks',
#   'alshabaab',
#   'episode',
#   'fallacies',
#   'explore',
#   'fallacy',
#   'stock',
#   'exchange',
#   'economy',
#   'episode',
#   'senior',
#   'business',
#   'journalist',
#   'julians',
#   'amboko',
#   'sits',
#   'kwame',
#   'owino',
#   'defending',
#   'position',
#   'real',
#   'estate',
#   'lawyer',
#   'peter',
#   'mwangi',
#   'taking',
#   'contrary',
#   'view',
#   'eliasn',
#   'makori',
#   'speaks',
#   'jonathan',
#   'cross',
#   'elite',
#   'athletes',
#   'director',
#   'honolulu',
#   'marathon',
#   'challenges',
#   'faced',
#   'episode',
#   'elias',
#   'makori',
#   'travels',
#   'hawaii',
#   'unravel',
#   'story',
#   'ibrahim',
#   'hussein',
#   'week',
#   'discover',
#   'actually',
#   'lot',
#   'money',
#   'go',
#   'away',
#   'pretty',
#   'quickly',
#   'working',
#   'scale',
#   'fictional',
#   'episode',
#   'series',
#   'seek',
#   'explore',
#   'rise',
#   'middle',
#   'class',
#   'mwai',
#   'kibaki',
#   'presidency',
#   'episode',
#   'explore',
#   'family',
#   'situation',
#   'talk',
#   'silas',
#   'miami',
#   'maxine',
#   'wabosha',
#   'content',
#   'creator',
#   'businesswoman',
#   'namu',
#   'award',
#   'winning',
#   'journalist',
#   'maxine',
#   'wabosha',
#   'content',
#   'creator',
#   'businesswoman',
#   'wives',
#   'die',
#   'society',
#   'quite',
#   'sure',
#   'widowed',
#   'man',
#   'men',
#   'find',
#   'lost',
#   'without',
#   'emotional',
#   'support',
#   'episode',
#   'three',
#   'men',
#   'talk',
#   'like',
#   'raise',
#   'children',
#   'without',
#   'mothers',
#   'also',
#   'talk',
#   'broke',
#   'news',
#   'kids',
#   'three',
#   'men',
#   'talk',
#   'pressure',
#   'imposed',
#   'move',
#   'marry',
#   'losing',
#   'wives',
#   'dive',
#   'challenges',
#   'settling',
#   'new',
#   'marriage',
#   'really',
#   'means',
#   'lose',
#   'episode',
#   'fareed',
#   'khimani',
#   'shares',
#   'experience',
#   'isolation',
#   'human',
#   'new',
#   'arts',
#   'culture',
#   'podcast',
#   'devoted',
#   'amplifying',
#   'voices',
#   'leaders',
#   'redefining',
#   'means',
#   'muslim',
#   'today',
#   'world',
#   'expert',
#   'storytelling',
#   'interviews'],
#  ['episode',
#   'dive',
#   'world',
#   'laws',
#   'specifically',
#   'focusing',
#   'good',
#   'son',
#   'law',
#   'navigating',
#   'unique',
#   'relationship',
#   'challenging',
#   'right',
#   'approach',
#   'foster',
#   'loving',
#   'respectful',
#   'connection',
#   'spouse',
#   'parents',
#   'come',
#   'thursday',
#   'masengeli',
#   'sight',
#   'public',
#   'eye',
#   'resurfacing',
#   'dp',
#   'gachagua',
#   'visited',
#   'police',
#   'stand',
#   'ask',
#   'show',
#   'family',
#   'murdered',
#   'olympian',
#   'blames',
#   'police',
#   'acting',
#   'swiftly',
#   'save',
#   'daughter',
#   'tsc',
#   'kuppet',
#   'say',
#   'agrees',
#   'settle',
#   'pending',
#   'matters',
#   'talks'],
#  ['inspector',
#   'general',
#   'police',
#   'japhet',
#   'koome',
#   'tuesday',
#   'assured',
#   'journalists',
#   'protection',
#   'police',
#   'operations',
#   'meanwhile',
#   'douglas',
#   'kanja',
#   'kirocho',
#   'taken',
#   'oath',
#   'office',
#   'new',
#   'deputy',
#   'inspector',
#   'general',
#   'police',
#   'episode',
#   'trio',
#   'discus',
#   'state',
#   'national',
#   'security',
#   'among',
#   'major',
#   'talk',
#   'points',
#   'sound',
#   'engineer',
#   'kevin',
#   'maina',
#   'podcast',
#   'editor',
#   'james',
#   'smart',
#   'come',
#   'thursday',
#   'masengeli',
#   'sight',
#   'public',
#   'eye',
#   'resurfacing',
#   'dp',
#   'gachagua',
#   'visited',
#   'police',
#   'stand',
#   'ask',
#   'show',
#   'family',
#   'murdered',
#   'olympian',
#   'blames',
#   'police',
#   'acting',
#   'swiftly',
#   'save',
#   'daughter',
#   'tsc',
#   'kuppet',
#   'say',
#   'agrees',
#   'settle',
#   'pending',
#   'matters',
#   'talks'],
#  ['exploring',
#   'life',
#   'jaramogi',
#   'oginga',
#   'odinga',
#   'fight',
#   'patronage',
#   'turn',
#   'spotlight',
#   'west',
#   'benefits',
#   'get',
#   'narrative',
#   'corrupt',
#   'continent',
#   'come',
#   'thursday',
#   'masengeli',
#   'sight',
#   'public',
#   'eye',
#   'resurfacing',
#   'dp',
#   'gachagua',
#   'visited',
#   'police',
#   'stand',
#   'ask',
#   'show',
#   'family',
#   'murdered',
#   'olympian',
#   'blames',
#   'police',
#   'acting',
#   'swiftly',
#   'save',
#   'daughter',
#   'tsc',
#   'kuppet',
#   'say',
#   'agrees',
#   'settle',
#   'pending',
#   'matters',
#   'talks'],
#  ['episode',
#   'leila',
#   'mohammed',
#   'mary',
#   'wambui',
#   'dominick',
#   'obala',
#   'discuss',
#   'killing',
#   'nhif',
#   'staff',
#   'cctv',
#   'footage',
#   'revealed',
#   'shot',
#   'dead',
#   'city',
#   'street',
#   'come',
#   'thursday',
#   'masengeli',
#   'sight',
#   'public',
#   'eye',
#   'resurfacing',
#   'dp',
#   'gachagua',
#   'visited',
#   'police',
#   'stand',
#   'ask',
#   'show',
#   'family',
#   'murdered',
#   'olympian',
#   'blames',
#   'police',
#   'acting',
#   'swiftly',
#   'save',
#   'daughter',
#   'tsc',
#   'kuppet',
#   'say',
#   'agrees',
#   'settle',
#   'pending',
#   'matters',
#   'talks'],
#  ['nakukulalas',
#   'turkana',
#   'center',
#   'kenya',
#   'oil',
#   'prospects',
#   'one',
#   'finds',
#   'state',
#   'despair',
#   'first',
#   'oil',
#   'pad',
#   'christened',
#   'ngamia',
#   'one',
#   'imposing',
#   'structure',
#   'manyatta',
#   'around',
#   'oil',
#   'prospecting',
#   'activities',
#   'stalled',
#   'community',
#   'gone',
#   'back',
#   'ways',
#   'profile',
#   'perfect',
#   'stand',
#   'kenya',
#   'government',
#   'tullow',
#   'oil',
#   'turkana',
#   'people',
#   'full',
#   'display',
#   'epsiode',
#   'set',
#   'stage',
#   'black',
#   'gold',
#   'promised',
#   'turkana',
#   'people',
#   'refused',
#   'materialise',
#   'natural',
#   'justice',
#   'narrative',
#   'podcast',
#   'follows',
#   'individuals',
#   'communities',
#   'forced',
#   'frontline',
#   'climate',
#   'change',
#   'conflicts',
#   'around',
#   'lake',
#   'region',
#   'push',
#   'back',
#   'using',
#   'kenyan',
#   'courts',
#   'preserve',
#   'dignity',
#   'communal',
#   'lands',
#   'face',
#   'huge',
#   'challenges',
#   'sandwiched',
#   'big',
#   'government',
#   'chinese',
#   'contractors',
#   'western',
#   'corporations',
#   'come',
#   'thursday',
#   'masengeli',
#   'sight',
#   'public',
#   'eye',
#   'resurfacing',
#   'dp',
#   'gachagua',
#   'visited',
#   'police',
#   'stand',
#   'ask',
#   'show',
#   'family',
#   'murdered',
#   'olympian',
#   'blames',
#   'police',
#   'acting',
#   'swiftly',
#   'save',
#   'daughter',
#   'tsc',
#   'kuppet',
#   'say',
#   'agrees',
#   'settle',
#   'pending',
#   'matters',
#   'talks'],
#  ['episode',
#   'money',
#   'moves',
#   'host',
#   'brian',
#   'george',
#   'takes',
#   'captivating',
#   'exploration',
#   'dynamic',
#   'relationship',
#   'instant',
#   'gratification',
#   'effective',
#   'planning',
#   'budgeting',
#   'know',
#   'feeling',
#   'urge',
#   'splurge',
#   'something',
#   'exciting',
#   'right',
#   'even',
#   'means',
#   'sacrificing',
#   'long',
#   'term',
#   'financial',
#   'goals',
#   'fear',
#   'episode',
#   'learn',
#   'possible',
#   'indulge',
#   'desires',
#   'still',
#   'staying',
#   'track',
#   'financially',
#   'filit',
#   'audio',
#   'visual',
#   'podcast',
#   'seeks',
#   'provide',
#   'platform',
#   'financial',
#   'literacy',
#   'personal',
#   'finance',
#   'podcast',
#   'hosts',
#   'guests',
#   'discuss',
#   'debt',
#   'management',
#   'savings',
#   'investment',
#   'opportunities',
#   'planning',
#   'retirement',
#   'tax',
#   'education',
#   'many',
#   'topics',
#   'revolve',
#   'around',
#   'prudence',
#   'money',
#   'growing',
#   'wealth',
#   'weekly',
#   'podcast',
#   'hosted',
#   'brian',
#   'george',
#   'business',
#   'journalist',
#   'nation',
#   'media',
#   'group',
#   'produced',
#   'edited',
#   'kevin',
#   'maina',
#   'come',
#   'thursday',
#   'masengeli',
#   'sight',
#   'public',
#   'eye',
#   'resurfacing',
#   'dp',
#   'gachagua',
#   'visited',
#   'police',
#   'stand',
#   'ask',
#   'show',
#   'family',
#   'murdered',
#   'olympian',
#   'blames',
#   'police',
#   'acting',
#   'swiftly',
#   'save',
#   'daughter',
#   'tsc',
#   'kuppet',
#   'say',
#   'agrees',
#   'settle',
#   'pending',
#   'matters',
#   'talks'],
#  ['george',
#   'gachui',
#   'co',
#   'founder',
#   'mookh',
#   'africa',
#   'recently',
#   'joined',
#   'mavericks',
#   'share',
#   'remarkable',
#   'journey',
#   'insights',
#   'building',
#   'groundbreaking',
#   'platform',
#   'captivating',
#   'discussion',
#   'unveiled',
#   'essence',
#   'mookh',
#   'profound',
#   'impact',
#   'made',
#   'come',
#   'thursday',
#   'masengeli',
#   'sight',
#   'public',
#   'eye',
#   'resurfacing',
#   'dp',
#   'gachagua',
#   'visited',
#   'police',
#   'stand',
#   'ask',
#   'show',
#   'family',
#   'murdered',
#   'olympian',
#   'blames',
#   'police',
#   'acting',
#   'swiftly',
#   'save',
#   'daughter',
#   'tsc',
#   'kuppet',
#   'say',
#   'agrees',
#   'settle',
#   'pending',
#   'matters',
#   'talks'],
#  ['episode',
#   'nfm',
#   'drive',
#   'chat',
#   'dr',
#   'ajwa',
#   'haji',
#   'shares',
#   'sad',
#   'horrifying',
#   'fgm',
#   'experience',
#   'using',
#   'experience',
#   'campaign',
#   'fgm',
#   'community',
#   'catch',
#   'nfmdrivechat',
#   'nation',
#   'fm',
#   'drive',
#   'weekdays',
#   'pm',
#   'pm',
#   'livestream',
#   'www',
#   'ntvkenya',
#   'com',
#   'nationfm',
#   'nfmdrivechat',
#   'come',
#   'thursday',
#   'masengeli',
#   'sight',
#   'public',
#   'eye',
#   'resurfacing',
#   'dp',
#   'gachagua',
#   'visited',
#   'police',
#   'stand',
#   'ask',
#   'show',
#   'family',
#   'murdered',
#   'olympian',
#   'blames',
#   'police',
#   'acting',
#   'swiftly',
#   'save',
#   'daughter',
#   'tsc',
#   'kuppet',
#   'say',
#   'agrees',
#   'settle',
#   'pending',
#   'matters',
#   'talks'],
#  ['episode',
#   'elias',
#   'makori',
#   'speaks',
#   'jonathan',
#   'cross',
#   'elite',
#   'athletes',
#   'director',
#   'honolulu',
#   'marathon',
#   'challenges',
#   'faced',
#   'fighting',
#   'secure',
#   'kenyan',
#   'african',
#   'runners',
#   'marquee',
#   'entries',
#   'annually',
#   'run',
#   'marathon',
#   'hawaii',
#   'made',
#   'big',
#   'breakthrough',
#   'join',
#   'elias',
#   'makori',
#   'explores',
#   'world',
#   'athletics',
#   'pushing',
#   'limits',
#   'performance',
#   'welcome',
#   'world',
#   'running',
#   'come',
#   'thursday',
#   'masengeli',
#   'sight',
#   'public',
#   'eye',
#   'resurfacing',
#   'dp',
#   'gachagua',
#   'visited',
#   'police',
#   'stand',
#   'ask',
#   'show',
#   'family',
#   'murdered',
#   'olympian',
#   'blames',
#   'police',
#   'acting',
#   'swiftly',
#   'save',
#   'daughter',
#   'tsc',
#   'kuppet',
#   'say',
#   'agrees',
#   'settle',
#   'pending',
#   'matters',
#   'talks'],
#  ['week',
#   'travel',
#   'way',
#   'east',
#   'asembo',
#   'discuss',
#   'groundnuts',
#   'value',
#   'chain',
#   'capacity',
#   'impact',
#   'economy',
#   'siaya',
#   'county',
#   'come',
#   'back',
#   'speak',
#   'dr',
#   'lusike',
#   'wasilwa',
#   'super',
#   'foods',
#   'impact',
#   'covid',
#   'agribusiness',
#   'future',
#   'food',
#   'know',
#   'kalro',
#   'developed',
#   'well',
#   'varieties',
#   'banana',
#   'well',
#   'know',
#   'come',
#   'thursday',
#   'masengeli',
#   'sight',
#   'public',
#   'eye',
#   'resurfacing',
#   'dp',
#   'gachagua',
#   'visited',
#   'police',
#   'stand',
#   'ask',
#   'show',
#   'family',
#   'murdered',
#   'olympian',
#   'blames',
#   'police',
#   'acting',
#   'swiftly',
#   'save',
#   'daughter',
#   'tsc',
#   'kuppet',
#   'say',
#   'agrees',
#   'settle',
#   'pending',
#   'matters',
#   'talks'],
#  ['episode',
#   'intern',
#   'shares',
#   'story',
#   'rejection',
#   'traumatised',
#   'says',
#   'dated',
#   'years',
#   'old',
#   'listen',
#   'share',
#   'feedback',
#   'living',
#   'truthfully',
#   'podcast',
#   'authentic',
#   'conversations',
#   'realities',
#   'african',
#   'man',
#   'discovering',
#   'oneself',
#   'owning',
#   'choices',
#   'building',
#   'spirituality',
#   'parenting',
#   'navigating',
#   'relationships',
#   'work',
#   'business',
#   'life',
#   'hosted',
#   'byamani',
#   'maranga',
#   'award',
#   'winning',
#   'podcaster',
#   'communications',
#   'specialist',
#   'come',
#   'thursday',
#   'masengeli',
#   'sight',
#   'public',
#   'eye',
#   'resurfacing',
#   'dp',
#   'gachagua',
#   'visited',
#   'police',
#   'stand',
#   'ask',
#   'show',
#   'family',
#   'murdered',
#   'olympian',
#   'blames',
#   'police',
#   'acting',
#   'swiftly',
#   'save',
#   'daughter',
#   'tsc',
#   'kuppet',
#   'say',
#   'agrees',
#   'settle',
#   'pending',
#   'matters',
#   'talks'],
#  ['widely',
#   'accepted',
#   'societies',
#   'men',
#   'providers',
#   'provide',
#   'build',
#   'career',
#   'business',
#   'handle',
#   'failure',
#   'success',
#   'motivates',
#   'listen',
#   'share',
#   'feedback',
#   'living',
#   'truthfully',
#   'podcast',
#   'authentic',
#   'conversations',
#   'realities',
#   'african',
#   'man',
#   'discovering',
#   'oneself',
#   'owning',
#   'choices',
#   'building',
#   'spirituality',
#   'parenting',
#   'navigating',
#   'relationships',
#   'work',
#   'business',
#   'life',
#   'hosted',
#   'byamani',
#   'maranga',
#   'award',
#   'winning',
#   'podcaster',
#   'communications',
#   'specialist',
#   'come',
#   'thursday',
#   'masengeli',
#   'sight',
#   'public',
#   'eye',
#   'resurfacing',
#   'dp',
#   'gachagua',
#   'visited',
#   'police',
#   'stand',
#   'ask',
#   'show',
#   'family',
#   'murdered',
#   'olympian',
#   'blames',
#   'police',
#   'acting',
#   'swiftly',
#   'save',
#   'daughter',
#   'tsc',
#   'kuppet',
#   'say',
#   'agrees',
#   'settle',
#   'pending',
#   'matters',
#   'talks']]
